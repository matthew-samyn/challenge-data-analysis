# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

# %%
df = pd.read_csv('house_data_ultimate_cleaned', index_col='Unnamed: 0')

# %%
df.head()
# Out:
#     Area   Price State_of_building  Facades  Bedrooms    Kitchen Furnished  \
# 0  123.0  200000              Good      3.0       2.0  Installed        No
# 1  255.0  698000    Just renovated      4.0       4.0  Installed        No
# 2  234.0  499000            As new      NaN       5.0        NaN        No
# 3  219.0  717000            As new      NaN       4.0        NaN        No
# 4  156.0  429000              Good      4.0       4.0  Installed        No
#
#   Open_fire  Zip_code  Land_surface Terrace  Terrace_surface Swimming_pool  \
# 0        No      3294         429.0      No                0            No
# 1        No      2070        1210.0      No                0            No
# 2        No      8800         744.0      No                0            No
# 3        No      8000         760.0      No                0            No
# 4        No      8800         419.0      No                0            No
#
#   Subtype_property Garden  Garden_surface   Regions  Price_per_square_meter
# 0            house    Yes             350  Flanders                 1626.02
# 1            villa     No               0  Flanders                 2737.25
# 2            villa     No               0  Flanders                 2132.48
# 3            house     No               0  Flanders                 3273.97
# 4            villa    Yes              90  Flanders                 2750.00

# %%
df_garden.Garden.value_counts()
# Out:
# Yes    2690
# Name: Garden, dtype: int64

# %%
df_garden.Garden_surface.value_counts()
# Out:
# 100     71
# 200     63
# 300     62
# 50      62
# 150     61
#         ..
# 1270     1
# 1260     1
# 1254     1
# 1244     1
# 2043     1
# Name: Garden_surface, Length: 699, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7801 entries, 0 to 8332
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area                    7801 non-null   float64
#  1   Price                   7801 non-null   int64
#  2   State_of_building       5889 non-null   object
#  3   Facades                 6256 non-null   float64
#  4   Bedrooms                7746 non-null   float64
#  5   Kitchen                 5601 non-null   object
#  6   Furnished               7801 non-null   object
#  7   Open_fire               7801 non-null   object
#  8   Zip_code                7801 non-null   int64
#  9   Land_surface            7801 non-null   float64
#  10  Terrace                 7801 non-null   object
#  11  Terrace_surface         7801 non-null   int64
#  12  Swimming_pool           7801 non-null   object
#  13  Subtype_property        7801 non-null   object
#  14  Garden                  7801 non-null   object
#  15  Garden_surface          7801 non-null   int64
#  16  Regions                 7801 non-null   object
#  17  Price_per_square_meter  7801 non-null   float64
# dtypes: float64(5), int64(4), object(9)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                Area         Price      Facades     Bedrooms    Zip_code  \
# count   7801.000000  7.801000e+03  6256.000000  7746.000000  7801.00000
# mean     227.569414  4.712033e+05     2.965793     3.671572  5563.62774
# std      199.199319  4.385355e+05     0.855572     1.695187  3036.51355
# min       30.000000  2.500000e+03     1.000000     1.000000  1000.00000
# 25%      140.000000  2.490000e+05     2.000000     3.000000  2610.00000
# 50%      180.000000  3.390000e+05     3.000000     3.000000  6000.00000
# 75%      253.000000  4.990000e+05     4.000000     4.000000  8560.00000
# max    10500.000000  3.000000e+06    16.000000    50.000000  9992.00000
#
#         Land_surface  Terrace_surface  Garden_surface  Price_per_square_meter
# count    7801.000000      7801.000000    7.801000e+03             7801.000000
# mean     1360.465325        14.066402    5.926766e+02             2075.943951
# std     13430.721793       230.233928    1.706773e+04             1070.603940
# min         1.000000         0.000000    0.000000e+00               15.050000
# 25%       193.000000         0.000000    0.000000e+00             1422.760000
# 50%       380.000000         0.000000    0.000000e+00             1945.310000
# 75%       842.000000        15.000000    1.000000e+02             2482.140000
# max    907540.000000     20194.000000    1.134500e+06            16086.960000

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.regplot(x = 'Area', y='Price' , col='Regions',data=df,ax=ax)
plt.xlim(0, 1000)
plt.ylim(0, 10000000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-724f21a7b2b3> in <module>
#       1 fig,ax = plt.subplots(figsize=(8,6))
# ----> 2 sns.regplot(x = 'Area', y='Price' , col='Regions',data=df,ax=ax)
#       3 plt.xlim(0, 1000)
#       4 plt.ylim(0, 10000000)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: regplot() got an unexpected keyword argument 'col'

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.distplot(df['Price'],kde=False,ax=ax)
plt.xlim(0, 2000000)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price (in millions)')
plt.ylabel('Freqency')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Freqency')

# %%
d = sns.displot(data=df, x="Price", hue="Regions", multiple="stack")
plt.title('Sale price vs Regions')
plt.xlabel('Sale price (in millions)')
plt.ylabel('Freqency')
plt.xlim(0, 2000000)
# Out:
# (0.0, 2000000.0)

# %%
d = sns.displot(data=df, x="Price", hue="Garden", multiple="stack")
plt.title('Sale price vs Garden')
plt.xlabel('Sale price (in millions)')
plt.ylabel('Freqency')
plt.xlim(0, 2000000)
# Out:
# (0.0, 2000000.0)

# %%
sns.displot(data=df, x="Price", hue="Regions", multiple="stack")
plt.title('Sale price (under 1 million) vs Regions')
plt.xlabel('Sale price (in millions)')
plt.ylabel('Freqency')
plt.xlim(0, 1000000)
# Out:
# (0.0, 1000000.0)

# %%
sns.displot(data=df, x='Price_per_square_meter', hue="Regions", multiple="stack")
plt.title('Price per m2 vs Regions')
plt.xlabel('Price per m2')
plt.ylabel('Freqency')
plt.xlim(0, 5000)
# Out:
# (0.0, 5000.0)

# %%
sns.displot(data=df, x='Area', hue="Regions", multiple="stack")
plt.title('Area vs Regions')
plt.xlabel('Area (in m2)')
plt.ylabel('Freqency')
plt.xlim(0, 700)
# Out:
# (0.0, 700.0)

# %%
sns.countplot(data=df, x="Regions")
plt.title('Regions of houses')
plt.ylabel('Freqency')
# Out:
# Text(0, 0.5, 'Freqency')

# %%
sns.scatterplot(x="Subtype_property", y="Price_per_square_meter", data=df)
# Out:
# <AxesSubplot:xlabel='Subtype_property', ylabel='Price_per_square_meter'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7801 entries, 0 to 8332
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area                    7801 non-null   float64
#  1   Price                   7801 non-null   int64
#  2   State_of_building       5889 non-null   object
#  3   Facades                 6256 non-null   float64
#  4   Bedrooms                7746 non-null   float64
#  5   Kitchen                 5601 non-null   object
#  6   Furnished               7801 non-null   object
#  7   Open_fire               7801 non-null   object
#  8   Zip_code                7801 non-null   int64
#  9   Land_surface            7801 non-null   float64
#  10  Terrace                 7801 non-null   object
#  11  Terrace_surface         7801 non-null   int64
#  12  Swimming_pool           7801 non-null   object
#  13  Subtype_property        7801 non-null   object
#  14  Garden                  7801 non-null   object
#  15  Garden_surface          7801 non-null   int64
#  16  Regions                 7801 non-null   object
#  17  Price_per_square_meter  7801 non-null   float64
# dtypes: float64(5), int64(4), object(9)
# memory usage: 1.4+ MB

# %%
print('Some statistics of the house price ')
print(df['Price'].describe())
print()
print('house price median')
print(df['Price'].median())
# Out:
# Some statistics of the house price
# count    7.801000e+03
# mean     4.712033e+05
# std      4.385355e+05
# min      2.500000e+03
# 25%      2.490000e+05
# 50%      3.390000e+05
# 75%      4.990000e+05
# max      3.000000e+06
# Name: Price, dtype: float64
#
# house price median
# 339000.0

# %%
fig,ax = plt.subplots(figsize=(8,10))
correlation = df.select_dtypes(include=['float64','int64']).corr()
sns.heatmap(correlation,ax=ax,vmax=1,square=True)
plt.title('Numeric Feature heatmap')
# Out:
# Text(0.5, 1.0, 'Numeric Feature heatmap')

# %%
fig,ax = plt.subplots(figsize=(15,6))
sns.regplot(x = 'Area', y='Price' , data=df,ax=ax)
plt.ylim(0, 4000000)
plt.xlim(0, 2000)
plt.title('Area vs Price') 
plt.show()

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue= 'Regions', col="Regions", height=4)
g.map(hexbin, "Area", "Price_per_square_meter", extent=[0, 500, 0, 7500]);

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue= 'State_of_building', col='State_of_building', height=4)
g.map(hexbin, "Area", "Price_per_square_meter", extent=[0, 500, 0, 7500]);
plt.title('State of the building')
plt.xlabel('Area (in m2)')
plt.ylabel('Freqency')
# Out:
# Text(875.224375, 0.5, 'Freqency')

# %%
g = sns.FacetGrid(df, hue='Regions',col="Regions")
g.map(sns.histplot, "Price")

# %%
print(df.select_dtypes(include=['object']).columns)
# Out:
# Index(['State_of_building', 'Kitchen', 'Furnished', 'Open_fire', 'Terrace',
#        'Swimming_pool', 'Subtype_property', 'Garden', 'Regions'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'State_of_building', y = 'Price_per_square_meter',  data = df,ax=ax, order=["To be done up", "Good", "Just renovated", "As new"], palette= "viridis", showfliers = False)
plt.title('State of building vs Price per m2')
plt.xlabel('State of the building')
plt.ylabel('Price per m2')
#ticks = plt.setp(ax.get_xticklabels(),rotation=45)
plt.ylim(0, 5000)
# Out:
# (0.0, 5000.0)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'State_of_building', y = 'Price',  data = df,ax=ax, order=["To be done up", "Good", "Just renovated", "As new"], palette= "viridis", showfliers = False)
plt.title('State of building vs Price')
plt.xlabel('State of the building')
plt.ylabel('Price')
#ticks = plt.setp(ax.get_xticklabels(),rotation=45)
plt.ylim(0, 1500000)
# Out:
# (0.0, 1500000.0)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Regions', y = 'Price_per_square_meter',  data = df,ax=ax, showfliers = False)
plt.title('Regions vs Price per m2')
plt.xlabel('Regions')
plt.ylabel('Price per m2')
plt.ylim(0, 7000)
# Out:
# (0.0, 7000.0)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Regions', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Regions vs Price')
plt.xlabel('Regions')
plt.ylabel('Price (in millions)')
plt.ylim(0, 2800000)
# Out:
# (0.0, 2800000.0)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Garden', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Garden vs Price')
# Out:
# Text(0.5, 1.0, 'Garden vs Price')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Subtype_property', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Subtype_property vs Price')
ticks = plt.setp(ax.get_xticklabels(),rotation=45)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Swimming_pool', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Is having a swimming pool linked to a higher price?')
# Out:
# Text(0.5, 1.0, 'Is having a swimming pool linked to a higher price?')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Furnished', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Is fursnihed linked to a higher price?')
# Out:
# Text(0.5, 1.0, 'Is fursnihed linked to a higher price?')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Open_fire', y = 'Price',  data = df,ax=ax, showfliers = False)
plt.title('Is having an open-fire linked to a higher price?')
# Out:
# Text(0.5, 1.0, 'Is having an open-fire linked to a higher price?')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'Kitchen', y = 'Price',  data = df,ax=ax, order=["Not installed", "Installed", "Semi equipped", "Hyper equipped"], palette= "viridis", showfliers = False)
plt.title('Is kitchen type linked to a higher price?')
ticks = plt.setp(ax.get_xticklabels(),rotation=45)

# %%
sns.relplot(x="Garden_surface", y="Price", data=df, hue='Swimming_pool')
plt.show()

# %%
df_garden = df[df['Garden_surface'] > 1]

# %%
sns.relplot(x="Garden_surface", y="Price", data=df_garden, hue='Swimming_pool')
plt.xlim(0, 5000)
plt.show()
